# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
originalfeatures = df.columns
print('originalfetures counts', len(originalfeatures))
print('originalfetures counts', originalfeatures)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-88e705c17c92> in <module>
# ----> 1 originalfeatures = df.columns
#       2 print('originalfetures counts', len(originalfeatures))
#       3 print('originalfetures counts', originalfeatures)
#       4 print(df.head())
#
# NameError: name 'df' is not defined

# %%
alpha = 0.10
plt.figure(figsize=(10,10))
plt.subplot(121)
loc_x = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
loc_y = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
plt.scatter(loc_x, loc_y, c="red")
plt.title('loc_x and loc_y')
plt.subplot(122)
lat = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
lon = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
plt.scatter(lon, lat, c='blue')
plt.title('lat and lon')

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = house_data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(house_data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
