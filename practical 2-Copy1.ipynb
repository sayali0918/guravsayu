# %%
import pandas as pd
df=pd.read_csv('Salaries.csv')
df.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3708\3483517315.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Salaries.csv')
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# ...

# %%
df.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df=df.drop(columns=['BasePay'])
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df.JobTitle.value_counts()
# Out:
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
df.Year.value_counts()
# Out:
# 2014    38123
# 2013    37606
# 2012    36766
# 2011    36159
# Name: Year, dtype: int64

# %%
df=pd.read_csv('employees.csv')
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
df["EMAIL"]=="JSEO"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# Name: EMAIL, dtype: bool

# %%
df[df["JOB_ID"]!="ST_CLERK"]
# Out:
#     EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald    OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas       Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer      Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael   Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat         Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan      Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann        Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley     Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William       Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven        King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena     Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
df[df["SALARY"]==2600]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198     Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199    Douglas     Grant    DGRANT  650.507.9844  13-JAN-08
# 27          118        Guy    Himuro   GHIMURO  515.127.4565  15-NOV-06
#
#       JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0   SH_CLERK    2600             -         124             50
# 1   SH_CLERK    2600             -         124             50
# 27  PU_CLERK    2600             -         114             30

# %%
import numpy as nm

# %%
df.JOB_ID.value_counts()
# Out:
# ST_CLERK      16
# ST_MAN         5
# PU_CLERK       5
# FI_ACCOUNT     5
# IT_PROG        5
# AD_VP          2
# SH_CLERK       2
# AC_ACCOUNT     1
# AD_ASST        1
# AC_MGR         1
# PR_REP         1
# FI_MGR         1
# HR_REP         1
# PU_MAN         1
# MK_REP         1
# MK_MAN         1
# AD_PRES        1
# Name: JOB_ID, dtype: int64

# %%
df[df['SALARY']>2300].value_counts()
# Out:
# EMPLOYEE_ID  FIRST_NAME   LAST_NAME    EMAIL     PHONE_NUMBER  HIRE_DATE  JOB_ID      SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 100          Steven       King         SKING     515.123.4567  17-JUN-03  AD_PRES     24000    -               -          90               1
# 138          Stephen      Stiles       SSTILES   650.121.2034  26-OCT-05  ST_CLERK    3200     -              123         50               1
# 126          Irene        Mikkilineni  IMIKKILI  650.124.1224  28-SEP-06  ST_CLERK    2700     -              120         50               1
# 127          James        Landry       JLANDRY   650.124.1334  14-JAN-07  ST_CLERK    2400     -              120         50               1
# 129          Laura        Bissot       LBISSOT   650.124.5234  20-AUG-05  ST_CLERK    3300     -              121         50               1
# 130          Mozhe        Atkinson     MATKINSO  650.124.6234  30-OCT-05  ST_CLERK    2800     -              121         50               1
# ...

# %%
df['FULL_NAME']=df['FIRST_NAME']+' '+df['LAST_NAME']

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
df.aggregate(['min','max','median','sum','mean'])
# Out:
# C:\Users\Shivamss\AppData\Local\Temp\ipykernel_13328\461620243.py:1: FutureWarning: ['FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER', 'HIRE_DATE', 'JOB_ID', 'COMMISSION_PCT', 'MANAGER_ID', 'FULL_NAME'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.aggregate(['min','max','median','sum','mean'])
#         EMPLOYEE_ID                                         FIRST_NAME  \
# min          100.00                                               Adam
# max          206.00                                            William
# median       124.50                                                NaN
# sum         6738.00  DonaldDouglasJenniferMichaelPatSusanHermannShe...
# mean         134.76                                                NaN
#
#                                                 LAST_NAME  \
# min                                              Atkinson
# ...

# %%
df.agg(['sum'])
# Out:
#      EMPLOYEE_ID                                         FIRST_NAME  \
# sum         6738  DonaldDouglasJenniferMichaelPatSusanHermannShe...
#
#                                              LAST_NAME  \
# sum  OConnellGrantWhalenHartsteinFayMavrisBaerHiggi...
#
#                                                  EMAIL  \
# sum  DOCONNELDGRANTJWHALENMHARTSTEPFAYSMAVRISHBAERS...
#
#                                           PHONE_NUMBER  \
# sum  650.507.9833650.507.9844515.123.4444515.123.55...
#
#                                              HIRE_DATE  \
# sum  21-JUN-0713-JAN-0817-SEP-0317-FEB-0417-AUG-050...
#
#                                                 JOB_ID  SALARY  \
# sum  SH_CLERKSH_CLERKAD_ASSTMK_MANMK_REPHR_REPPR_RE...  309116
#
#                                         COMMISSION_PCT  \
# sum   -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  ...
#
#                                             MANAGER_ID  DEPARTMENT_ID  \
# ...

# %%
df.agg(['min'])
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME   EMAIL  PHONE_NUMBER  HIRE_DATE  \
# min          100       Adam  Atkinson  AFRIPP  515.123.4444  01-MAY-03
#
#          JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID   FULL_NAME
# min  AC_ACCOUNT    2100             -          -              10  Adam Fripp

# %%
df.agg(['max'])
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME   EMAIL  PHONE_NUMBER  HIRE_DATE  \
# max          206    William    Whalen  WGIETZ  650.507.9844  30-SEP-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID      FULL_NAME
# max  ST_MAN   24000             -         205            110  William Gietz

# %%
df.agg(['mean'])
# Out:
# C:\Users\Shivamss\AppData\Local\Temp\ipykernel_13328\557892675.py:1: FutureWarning: ['FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER', 'HIRE_DATE', 'JOB_ID', 'COMMISSION_PCT', 'MANAGER_ID', 'FULL_NAME'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg(['mean'])
#       EMPLOYEE_ID   SALARY  DEPARTMENT_ID
# mean       134.76  6182.32           57.6

# %%
df.agg(['median'])
# Out:
# C:\Users\Shivamss\AppData\Local\Temp\ipykernel_13328\1246866402.py:1: FutureWarning: ['FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER', 'HIRE_DATE', 'JOB_ID', 'COMMISSION_PCT', 'MANAGER_ID', 'FULL_NAME'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg(['median'])
#         EMPLOYEE_ID  SALARY  DEPARTMENT_ID
# median        124.5  4600.0           50.0

# %%
df.agg({'SALARY':['sum','min','max','median','mean']})
# Out:
#            SALARY
# sum     309116.00
# min       2100.00
# max      24000.00
# median    4600.00
# mean      6182.32
